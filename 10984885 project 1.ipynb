# %%
import pandas as pd 
import seaborn as sn 
from matplotlib import pyplot as plt
import numpy as np

# %%
data=pd.read_csv('data.csv')

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# The data.info() makes it easy to identify null colums

# %%
data.rename(columns={'fixed acidity':'fixedacidity', 
                     'citric acid':'citricacid', 
                     'free sulfur dioxide':'free_sulfurdioxide', 
                     'total sulfur dioxide':'total_sulfurdioxide'})
# Out:
#         ID  fixedacidity  volatile acidity  citricacid  residual sugar  \
# 0        1           7.4             0.700        0.00             1.9
# 1        2           7.8             0.880        0.00             2.6
# 2        3           7.8             0.760        0.04             2.3
# 3        4          11.2             0.280        0.56             1.9
# 4        5           7.4             0.700        0.00             1.9
# ...    ...           ...               ...         ...             ...
# 1596  1597           5.9             0.550        0.10             2.2
# 1597  1598           6.3             0.510        0.13             2.3
# 1598  1599           5.9             0.645        0.12             2.0
# 1599  1600           6.0             0.310        0.47             3.6
# 1600  1601           7.2             0.390        0.44             2.6
#
#       chlorides  free_sulfurdioxide  total_sulfurdioxide  density    pH  \
# ...

# %%
data=data.rename(columns={'fixed acidity':'fixedacidity', 
                     'citric acid':'citricacid', 
                     'free sulfur dioxide':'free_sulfurdioxide', 
                     'total sulfur dioxide':'total_sulfurdioxide'})

# %%
data
# Out:
#         ID  fixedacidity  volatile acidity  citricacid  residual sugar  \
# 0        1           7.4             0.700        0.00             1.9
# 1        2           7.8             0.880        0.00             2.6
# 2        3           7.8             0.760        0.04             2.3
# 3        4          11.2             0.280        0.56             1.9
# 4        5           7.4             0.700        0.00             1.9
# ...    ...           ...               ...         ...             ...
# 1596  1597           5.9             0.550        0.10             2.2
# 1597  1598           6.3             0.510        0.13             2.3
# 1598  1599           5.9             0.645        0.12             2.0
# 1599  1600           6.0             0.310        0.47             3.6
# 1600  1601           7.2             0.390        0.44             2.6
#
#       chlorides  free_sulfurdioxide  total_sulfurdioxide  density    pH  \
# ...

# %%
data.head(60)
# Out:
#     ID  fixedacidity  volatile acidity  citricacid  residual sugar  chlorides  \
# 0    1           7.4             0.700        0.00             1.9      0.076
# 1    2           7.8             0.880        0.00             2.6      0.098
# 2    3           7.8             0.760        0.04             2.3      0.092
# 3    4          11.2             0.280        0.56             1.9      0.075
# 4    5           7.4             0.700        0.00             1.9      0.076
# 5    6           7.4             0.660        0.00             1.8      0.075
# 6    7           7.9             0.600        0.06             1.6      0.069
# 7    8           7.3             0.650        0.00             1.2      0.065
# 8    9           7.8             0.580        0.02             2.0      0.073
# 9   10           7.5             0.500        0.36             6.1      0.071
# 10  11           6.7             0.580        0.08             1.8      0.097
# ...

# %% [markdown]
# With data.head(60) shows the 60 rows which was truncated in the raw data

# %%
data.describe()
# Out:
#                 ID  fixedacidity  volatile acidity   citricacid  \
# count  1601.000000   1600.000000       1601.000000  1600.000000
# mean    801.000000      8.319875          0.527742     0.271175
# std     462.313206      1.740039          0.178981     0.194745
# min       1.000000      4.600000          0.120000     0.000000
# 25%     401.000000      7.100000          0.390000     0.090000
# 50%     801.000000      7.900000          0.520000     0.260000
# 75%    1201.000000      9.200000          0.640000     0.420000
# max    1601.000000     15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free_sulfurdioxide  total_sulfurdioxide  \
# count     1601.000000  1598.000000         1600.000000          1600.000000
# mean         2.538445     0.087487           15.886875            46.520000
# std          1.409138     0.047076           10.458487            32.977723
# min          0.900000     0.012000            1.000000             6.000000
# ...

# %% [markdown]
# data.describe() gives vivid explanation of the data

# %%
mean_FA=data.fixedacidity.mean()
mean_CA=data.fixedacidity.mean()
mean_CL=data.fixedacidity.mean()
mean_FSO=data.fixedacidity.mean()
mean_TSO=data.fixedacidity.mean()
mean_D=data.fixedacidity.mean()
mean_pH=data.fixedacidity.mean()
mean_quality=data.fixedacidity.mean()

# %%
print(mean_FA)
print(mean_CA)
print(mean_CL)
print(mean_FSO)
print(mean_TSO)
print(mean_D)
print(mean_pH)
print(mean_quality)
# Out:
# 8.319875000000001
# 8.319875000000001
# 8.319875000000001
# 8.319875000000001
# 8.319875000000001
# 8.319875000000001
# 8.319875000000001
# 8.319875000000001

# %% [markdown]
# The above code was written to know the mean of column described in the variable and also it will help us to fill the null data columns with their mean.

# %%
data['fixedacidity'] = data['fixedacidity'].fillna(mean_FA)
data['citricacid'] = data['citricacid'].fillna(mean_CA)
data['chlorides'] = data['chlorides'].fillna(mean_CL)
data['free_sulfurdioxide'] = data['free_sulfurdioxide'].fillna(mean_FSO)
data['total_sulfurdioxide'] = data['total_sulfurdioxide'].fillna(mean_TSO)
data['density'] = data['density'].fillna(mean_D)
data['pH'] = data['pH'].fillna(mean_pH)
data['quality'] = data['quality'].fillna(mean_quality)

# %%
data
# Out:
#         ID  fixedacidity  volatile acidity  citricacid  residual sugar  \
# 0        1           7.4             0.700        0.00             1.9
# 1        2           7.8             0.880        0.00             2.6
# 2        3           7.8             0.760        0.04             2.3
# 3        4          11.2             0.280        0.56             1.9
# 4        5           7.4             0.700        0.00             1.9
# ...    ...           ...               ...         ...             ...
# 1596  1597           5.9             0.550        0.10             2.2
# 1597  1598           6.3             0.510        0.13             2.3
# 1598  1599           5.9             0.645        0.12             2.0
# 1599  1600           6.0             0.310        0.47             3.6
# 1600  1601           7.2             0.390        0.44             2.6
#
#       chlorides  free_sulfurdioxide  total_sulfurdioxide  density        pH  \
# ...

# %%
mean=np.array([8.319875,0.271175,15.886875,46.52,0.9967456437500002,3.31110625,5.63625])
myLabels=['fixedacidity','citricacid','freeSO','totalSO','density','pH','quality',]
explode=(0,0.3,0,0,0.3,0,0)

plt.figure(figsize=(7,10))
plt.title('Mean Of specific columns', fontsize=9, fontweight='bold')
plt.style.use('ggplot')
plt.pie(mean,labels=myLabels,explode=explode,startangle=0,autopct='%.2f%%')
plt.legend(loc='upper left', fontsize=7)
plt.show()

# %% [markdown]
# ### __DEDUCTION FROM PIE CHART__

# %% [markdown]
# The pie chart shows the average value of pH,density,quality,total sulfur dioxide, free sulfur dioxide,fixed acidity and citric acid of the beverage produced.
#
# With the higher total sulfurdioxide showing in the chart it implies that, there is a high concentration of sulfur dioxide.
# This means, this beverage is not good for asthmatics as the higher concentration of sulfur serves as an antioxidant.
#
# **pH____** the pH shows the acidic content of the beverage and since it has an average value less than 7 it means that,the beverage has an acidic content which is high(**3.31**).

# %% [markdown]
# ## HISTOGRAPH FOR MODE OF SPECIFIC COLUMNS

# %%
mode_FA=data.fixedacidity.mode()
mode_CA=data.citricacid.mode()
mode_CL=data.chlorides.mode()
mode_FSO=data.free_sulfurdioxide.mode()
mode_TSO=data.total_sulfurdioxide.mode()
mode_D=data.density.mode()
mode_pH=data.pH.mode()
mode_quality=data.quality.mode()

# %%
print(mode_FA)
print(mode_CA)
print(mode_CL)
print(mode_FSO)
print(mode_TSO)
print(mode_D)
print(mode_pH)
print(mode_quality)
# Out:
# 0    7.2
# Name: fixedacidity, dtype: float64
# 0    0.0
# Name: citricacid, dtype: float64
# 0    0.08
# Name: chlorides, dtype: float64
# 0    6.0
# Name: free_sulfurdioxide, dtype: float64
# 0    28.0
# Name: total_sulfurdioxide, dtype: float64
# 0    0.9972
# Name: density, dtype: float64
# 0    3.3
# Name: pH, dtype: float64
# 0    5.0
# Name: quality, dtype: float64

# %%
mode=[7.2,0,0.08,6.0,28.0,0.9972,3.3,5.0]

plt.title('HISTOGRAPH OF PARTICULAR COLUMNS')
plt.hist(mode,ec='blue')
# Out:
# (array([3., 2., 2., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 0. ,  2.8,  5.6,  8.4, 11.2, 14. , 16.8, 19.6, 22.4, 25.2, 28. ]),
#  <BarContainer object of 10 artists>)

# %%
 data.quality
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1596    6.0
# 1597    6.0
# 1598    5.0
# 1599    6.0
# 1600    6.0
# Name: quality, Length: 1601, dtype: float64

# %%
data.corr()
# Out:
#                            ID  fixedacidity  volatile acidity  citricacid  \
# ID                   1.000000     -0.267899         -0.009544   -0.136810
# fixedacidity        -0.267899      1.000000         -0.255557    0.468411
# volatile acidity    -0.009544     -0.255557          1.000000   -0.388313
# citricacid          -0.136810      0.468411         -0.388313    1.000000
# residual sugar      -0.031589      0.114595          0.001877    0.096769
# chlorides            0.042709     -0.013779         -0.037119    0.033307
# free_sulfurdioxide   0.091738     -0.153031         -0.010797   -0.054206
# total_sulfurdioxide -0.112524     -0.112604          0.076003    0.036702
# density              0.019512     -0.000591          0.040369   -0.021164
# pH                   0.077703     -0.534673          0.203079   -0.319114
# sulphates           -0.124243      0.182291         -0.261364    0.203970
# alcohol              0.245028     -0.061858         -0.202672    0.059191
# ...

# %%
x= data.fixedacidity < data.pH

x.value_counts()
# Out:
# False    1600
# True        1
# dtype: int64

# %%
correLation=([15.900,4.000])
theLabels=('fixedacidity','pH')

# %%
plt.figure(figsize=(5,7))
plt.title('Correlation Between Fixedacidity And pH', fontsize=9, fontweight='bold')
plt.style.use('ggplot')
plt.pie(correLation,labels=theLabels,autopct='%.2f%%')
plt.legend(loc='upper left', fontsize=7)
plt.show()

# %% [markdown]
# ### DEDUCTION FROM PIE CHART

# %% [markdown]
# From the pie chart above we correlated the maximum value of fixedacidity and pH of the beverage
# It is deducted from the chart that, Commercially available beverages with a pH < 4.0 are potentially damaging to the dentition. Acids are added to beverages and compose a flavor profile giving the beverage a distinctive taste.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# From the above data and charts it was seen that the beverage has a **average total sulfurdioxide** larger than other columns which does not make the beverage suitable for asthmatic patients. Also the max pH which is equal to 4 indicates a good acidity content for consumption.
